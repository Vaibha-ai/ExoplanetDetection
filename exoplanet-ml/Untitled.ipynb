# %%
import requests
from lightkurve import search_lightcurve

# Set global timeout for requests
requests.adapters.DEFAULT_RETRIES = 5
requests.session().keep_alive = False
requests_timeout = 60  # 60 seconds

# Search and download the light curve
lc = search_lightcurve("Kepler-011442793").download(timeout=requests_timeout).PDCSAP_FLUX
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ...
